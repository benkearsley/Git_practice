# %%
# def solution(xs):
#     negative_panels = []
#     positive_panels = []
#     for panel in xs:
#         if panel < 0:
#             negative_panels.append(panel)
#         elif panel > 0:
#             positive_panels.append(panel)

#     positive_panels = sorted(positive_panels)
#     negative_panels = sorted(negative_panels)
    
#     product_panels = positive_panels
#     if len(negative_panels) % 2 == 0:
#         for panel in negative_panels:
#             product_panels.append(panel)

#     elif (len(negative_panels) % 2 == 1) & (len(negative_panels) > 1):
#         negative_panels.remove(negative_panels[len(negative_panels)-1])
#         # print(negative_panels)
#         for panel in negative_panels:
#             product_panels.append(panel)
#     # print(product_panels)
#     product = 1
#     for panel in product_panels:
#         product *= panel
#     if product == 1:
#         print(0)
#     else:
#         print(product)

def solution(xs):
    negative_panels = []
    positive_panels = []
    for panel in xs:
        if panel < 0:
            negative_panels.append(panel)
        elif panel > 0:
            positive_panels.append(panel)
    
    positive_panels = sorted(positive_panels)
    negative_panels = sorted(negative_panels)
    product_panels = positive_panels
    
    # if len(negative_panels) % 2 == 0:
    #     for panel in negative_panels:
    #         product_panels.append(panel)
    
    if (len(negative_panels) % 2 == 1) & (len(negative_panels) > 1):
        negative_panels.remove(negative_panels[len(negative_panels)-1])
        # print(negative_panels)
        # for panel in negative_panels:
        #     product_panels.append(panel)
        # print(product_panels)
    for panel in negative_panels:
        product_panels.append(panel)
    product = 1
    
    for panel in product_panels:
        product *= panel
    # All zeros
    if len(product_panels) == 0:
        print(str(0))
    elif product < 0:
        print(str(0))
    else:
        print(str(product))
        # return str(product)

# %%
# xs = [2,0,2,2,0]
# xs = [-5,-5,-4,0]
# xs = [0,0,0,0]
# xs = [2,-3,1,0,-5]
xs = [-3]
solution(xs)
